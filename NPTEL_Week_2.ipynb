# %% [markdown]
# ### Addition with Data Vectors

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# c(2,3,5,7) + c(-2,-3,-5,8)
# Out:
# [1]  0  0  0 15

# %%
# %%R
# c(2,3,5,7) + c(8,9)
# Out:
# [1] 10 12 13 16

# %%
# %%R
# c(2,3,5,7) + c(8,9,10)
# Out:
# [1] 10 12 15 15
# In addition: Warning message:
# In c(2, 3, 5, 7) + c(8, 9, 10) :
#   longer object length is not a multiple of shorter object length

# %% [markdown]
# ### Subtraction with Data Vectors

# %%
# %%R
# c(2,3,5,7) - c(-2,-3,-5,8)
# Out:
# [1]  4  6 10 -1

# %%
# %%R
# c(12,13,15,17) - c(8,9)
# Out:
# [1] 4 4 7 8

# %%
 # %%R
 c(12,13,15,17) - c(8,9,10)
# Out:
# [1] 4 4 5 9
# In addition: Warning message:
# In c(12, 13, 15, 17) - c(8, 9, 10) :
#   longer object length is not a multiple of shorter object length

# %% [markdown]
# ### Multiplication with Data Vectors

# %%
# %%R
# c(2,3,5,7) * c(-2,-3,-5,8)
# Out:
# [1]  -4  -9 -25  56

# %%
# %%R
# c(2,3,5,7) * c(8,9)
# Out:
# [1] 16 27 40 63

# %%
# %%R
# c(2,3,5,7) * c(8,9,10)
# Out:
# [1] 16 27 50 56
# In addition: Warning message:
# In c(2, 3, 5, 7) * c(8, 9, 10) :
#   longer object length is not a multiple of shorter object length

# %% [markdown]
# ### Division with Data Vectors

# %%
# %%R
# c(24,20,8,16) / c(3,4,2,8)
# Out:
# [1] 8 5 4 2

# %%
# %%R
# c(24,20,8,16) / c(4,2)
# Out:
# [1]  6 10  2  8

# %%
# %%R
# c(24,20,8,16) / c(4,2,8)
# Out:
# [1]  6 10  1  4
# In addition: Warning message:
# In c(24, 20, 8, 16)/c(4, 2, 8) :
#   longer object length is not a multiple of shorter object length

# %% [markdown]
# ### Assignment Operator

# %%
# %%R
# x = 20
# x
# Out:
# [1] 20

# %%
x = apple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2568/2343535301.py in <cell line: 0>()
# ----> 1 x = apple
#
# NameError: name 'apple' is not defined

# %%
x = "apple"
x
# Out:
# 'apple'

# %% [markdown]
# ### Knowing numbers and characters

# %%
# %%R
# x = 20
# is.numeric(x)
# Out:
# [1] TRUE

# %%
# %%R
# is.character(x)
# Out:
# [1] FALSE

# %%
# %%R
# y = "apple"
# is.character(x)
# Out:
# [1] FALSE

# %%
# %%R
# is.numeric(y)
# Out:
# [1] FALSE

# %% [markdown]
# ### Comment Operator

# %%
# x <- 20

# %% [markdown]
# ### Case Sensitivity in R

# %%
# %%R
# x <- 20
# x
# Out:
# [1] 20

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2568/3777217377.py in <cell line: 0>()
# ----> 1 X
#
# NameError: name 'X' is not defined

# %% [markdown]
# ### Combining values in a Data Vector

# %%
# %%R
# y = c(1,2,3,4,5)
# y
# Out:
# [1] 1 2 3 4 5

# %% [markdown]
# ### Mode

# %%
# %%R
# x = 6
# x
# mode(x)
# Out:
# [1] "numeric"

# %%
# %%R
# storage.mode(x)
# Out:
# [1] "double"

# %%
# %%R
# y = "apple"
# y
# mode(y)
# Out:
# [1] "character"

# %%
# %%R
# storage.mode(y)
# Out:
# [1] "character"

# %%
# %%R
# x = TRUE
# x
# mode(x)
# Out:
# [1] "logical"

# %%
# %%R
# storage.mode(x)
# Out:
# [1] "logical"

# %% [markdown]
# ### Infinity

# %%
# %%R
# 3/0
# Out:
# [1] Inf

# %%
# %%R
# 5 + Inf
# Out:
# [1] Inf

# %%
# %%R
# x = 5 + Inf
# is.finite(x)
# Out:
# [1] FALSE

# %%
# %%R
# is.infinite(x)
# Out:
# [1] TRUE

# %% [markdown]
# ### R as a Calculator

# %%
# %%R
# 2*3-4+5/6
# Out:
# [1] 2.833333

# %%
# %%R
# (2+3)*5 + 5 - 10
# Out:
# [1] 20

# %%
# %%R
# (((2+3)*5 + 5) - 10)/2
# Out:
# [1] 10

# %% [markdown]
# ### Operations with Scalar

# %%
# %%R
# c(2,3,5,7) + 10
# Out:
# [1] 12 13 15 17

# %%
# %%R
# c(12,13,15,17) - 10
# Out:
# [1] 2 3 5 7

# %%
# %%R
# c(2,3,5,7) * 10
# Out:
# [1] 20 30 50 70

# %%
# %%R
# c(12,13,15,17) / 10
# Out:
# [1] 1.2 1.3 1.5 1.7
